# %% [markdown]
# ## Limits on Bosonic Neutral Currents operator $-$ $\psi^2 H^2 D$
#
# This notebook plots the standard parameter space of heavy neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1TIpmkgOa63-8Sy75qh0YutI5XdRtiClU3aquUdmjqpc/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.HNLimits.Bosonic_NC import plot_tools
from src.HNLimits.Bosonic_NC import bosonic_neutral_tools

# %% [markdown]
# ## $\dfrac{C_\text{HN}}{\Lambda^2}$

# %%
case_neutral = bosonic_neutral_tools.Limits(flavor='neutral', invisible=False)

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-7,1e-3),
        #
        #
        'skip_ids': [
                #'babar'
                ],
        #
        'new_color': {
                #'na62': '#3FC1C9',FC5185,364F6B
                'na62': '#F5F5F5',
                'zinv': '#364F6B',
                'monophoton': '#FC5185',
                'sn': '#3FC1C9',
                'babar': '#EEBB4D' #'#E4D192'
                },
        #
        'new_dash': {
                'sn': (4,2)
                },
        #
        'new_labelpos': {
                'na62': (1.4e-3, 1.9e-4),
                'babar': (1.4e-3, 7.5e-5),
                'zinv': (1.4e-3, 1.3e-6),
                'monophoton': (1.4e-3, 6e-6),
                'sn': (72e-3, 2.2e-7)
                },
        #
        'new_rotation':{
                'sn':0
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_neutral, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Generating the Latex files

# %%
from src.HNLimits.Bosonic_NC import tex_tools as tex
tex.create_latex_doc(cases=[case_neutral])
# Out:
# Latexmk: This is Latexmk, John Collins, 19 Jan. 2017, version: 4.52c.
# Rule 'pdflatex': Rules & subrules not known to be previously run:
#    pdflatex
# Rule 'pdflatex': The following rules & subrules became out-of-date:
#       'pdflatex'
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  --interaction=nonstopmode -recorder  "/Users/sissa/Documents/GitHub/Heavy-Neutrino-Limits/tex_files/bosonicNC_plots.tex"'
# ------------
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.14159265-2.6-1.40.18 (TeX Live 2017) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/Users/sissa/Documents/GitHub/Heavy-Neutrino-Limits/tex_files/bosonicNC_plots.
# tex
# LaTeX2e <2017-04-15>
# Babel <3.10> and hyphenation patterns for 84 language(s) loaded.
# (/usr/local/texlive/2017/texmf-dist/tex/latex/revtex/revtex4-1.cls
# Document Class: revtex4-1 2010/07/25/20:33:00 4.1r (http://publish.aps.org/revt
# ...
