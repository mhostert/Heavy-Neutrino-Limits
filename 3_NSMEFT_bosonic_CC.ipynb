# %% [markdown]
# ## Limits on Bosonic Charged operator $-$ $\psi^2 H^2 D$
#
# This notebook plots the standard parameter space of heavy neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1TIpmkgOa63-8Sy75qh0YutI5XdRtiClU3aquUdmjqpc/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.HNLimits.Bosonic_CC import plot_tools
from src.HNLimits.Bosonic_CC import bosonic_charged_tools

# %% [markdown]
# ## $\dfrac{C_{\text{HN}\ell}^e}{\Lambda^2}$

# %%
case_electron = bosonic_charged_tools.Limits(flavor='e', invisible=False, nature='majorana')

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-10,5e-6),
        #
        'skip_ids': [
                ],
        #
        'new_color': {
                'borexino': '#BAABDA',
                'pienu_lowmass': '#E36387',
                'triumf': '#354259', 
                'pienu_2017': '#BFB051', 
                't2k': '#FA697C',
                'kenu': '#FFCAC8',
                'na62': '#8DCBE6',
                'charm': '#43919B',
                'bebc_barouki': '#8F4068',
                'belle': '#423F3E', 
                'atlas_2019_prompt': '#120078', 
                'atlas_2022': '#A799B7',
                'cms_2022': '#FF9668', 
                'cms_2018': '#7579E7',
                'pmns_unitarity': '#52057B'
                },
        #
        'new_dash': {
                },
        #
        'new_labelpos': {
                'pienu_lowmass': (1.4e-3, 1.2e-7),
                'borexino': (4e-3, 2.6e-8),
                'triumf': (26e-3, 5e-9),
                'pienu_2017': (60e-3, 8e-10),
                'na62': (124e-3, 1e-9),
                't2k': (540e-3, 1e-9),
                'kenu': (1.9e-1, 4.3e-9),
                'charm': (2.2,9e-9),
                'bebc_barouki': (1,2.4e-9),
                'atlas_2022': (4.4,1.2e-8),
                'cms_2022': (14,3e-8),
                'atlas_2019_prompt': (24,5e-8),
                'belle': (2.2,5e-8),
                'pmns_unitarity': (1e1, 7e-7),
                'cms_2018': (50, 9e-8)
                },
        #
        'new_rotation':{
                'charm':90,
                't2k': 90,
                'cms_2022': 90,
                'belle': 90,
                'na62': 90
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_electron, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C^\mu_{\text{HN}\ell}}{\Lambda^2}$

# %%
case_muon = bosonic_charged_tools.Limits(flavor='mu', invisible=False, nature='majorana')

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-10,5e-6),
        #
        'skip_ids': [
            'delphi_short',
            't2k_lowmass',
            'cms_8tev',
            'cms_2018_dilepton'
        ],
        #
        'new_color': {
            'psi': '#A0C3D2', 
            'pienu_le': '#F29191',
            'pienu_he': '#F29191',
            'microboone_higgs': '#444444',
            't2k_lowmass': '#381460', 
            't2k': '#FA697C', 
            'kek': '#BAABDA', 
            'na62': '#8DCBE6', 
            'nutev': '#41AEA9',
            'bebc': '#8F4068',
            'na3': '#8BCDCD', 
            'atlas_2019_prompt': '#120078', 
            'atlas_2022': '#A799B7',
            'cms_2022': '#FF9668', 
            'cms_2018_trilepton': '#7579E7',
            'pmns_unitarity': '#52057B',
            'mue': '#FC92E3',
            'e949': '#F1C93B'
        },
        #
        'new_dash': {
        },
        #
        'new_labelpos': {
            'psi': (10e-3,4e-8),
            'pienu_le': (21e-3,10e-8),
            'pienu_he': (20e-3,2e-8),
            't2k': (3e-1,4e-10),
            'microboone_higgs': (80e-3,9e-9),
            'na3': (1.1,6e-8),
            'nutev': (1.98,6.2e-9),
            'bebc': (1.98,2.2e-8),
            'na62': (4.1e-1, 1.8e-9),
            'cms_2022': (1.6e1,20e-9),
            'atlas_2019_prompt': (2e1,4.8e-8),
            'atlas_2022': (8,7.4e-9),
            'pmns_unitarity': (1e1,2e-7),
            'kek': (54e-3,38e-9),
            'cms_2018_trilepton': (52,6.4e-8),
            'mue': (1.4e-3, 8e-7),
            'e949': (1.56e-1,0.52e-9)
        },
        'new_rotation': {
            'pienu_le': 90,
            'microboone_higgs': -42,
            'na3': -36,
            'nutev': 90,
            'bebc': 90,
            'na62': 90,
            'cms_2022': 90,
            'kek': -42,
            'e949': -42
        }
    }

fig, ax = plot_tools.std_plot_limits(case_muon, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C^{\tau}_{\text{{NH}}\ell}}{\Lambda^2}$

# %%
case_tau = bosonic_charged_tools.Limits(flavor='tau', invisible=False, nature='majorana')

# %%
kwargs = {
    'xrange': (1e-3,1e2),
    'yrange': (1e-9,5e-5),
    #
    'skip_ids': [
            'charm',
            'atlas_2022'
                ],
    #
    'new_color': {
        'd_decay': '#E96479',
        'ds_decay': '#F5E9CF',
        'b_decay': '#7DB9B6',
        'pmns_unitarity': '#52057B',
        'taue': '#454545', 
        'taumu': '#005F99'
    }
    ,
    #
    'new_dash': {
        'taumu': (6,2)
    },
    #
    'new_labelpos': {
        'b_decay': (1.4e-3, 1.6e-5),
        'd_decay': (1.4e-3, 5e-6),
        'ds_decay': (4e-3, 5e-6),
        'pmns_unitarity': (1e1,5.4e-7),
        'taue': (1.4e-3,1.5e-6),
        'taumu': (1.4e-3,7e-7)
    },
    #
    "new_rotation": {

    }
}

fig, ax = plot_tools.std_plot_limits(case_tau, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Generating the Latex files

# %%
from src.HNLimits.Bosonic_CC import tex_tools as tex
tex.create_latex_doc(cases=[case_electron,case_muon,case_tau])
# Out:
# Latexmk: This is Latexmk, John Collins, 19 Jan. 2017, version: 4.52c.
# Rule 'pdflatex': Rules & subrules not known to be previously run:
#    pdflatex
# Rule 'pdflatex': The following rules & subrules became out-of-date:
#       'pdflatex'
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  --interaction=nonstopmode -recorder  "/Users/sissa/Documents/GitHub/Heavy-Neutrino-Limits/tex_files/bosonicCC_plots.tex"'
# ------------
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.14159265-2.6-1.40.18 (TeX Live 2017) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/Users/sissa/Documents/GitHub/Heavy-Neutrino-Limits/tex_files/bosonicCC_plots.
# tex
# LaTeX2e <2017-04-15>
# Babel <3.10> and hyphenation patterns for 84 language(s) loaded.
#
# ! LaTeX Error: File `revtex4-2.cls' not found.
#
# Type X to quit or <RETURN> to proceed,
# or enter new name. (Default extension: cls)
#
# ...
