# %% [markdown]
# ## Limits on Heavy Neutrinos
#
# This notebook plots the standard parameter space of heavy neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1p_fslIlThKMOThGl4leporUsogq9TmgXwILntUZOscg/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import *
from Nlimits import plot_tools
from Nlimits import hnl_tools

# %%
case_electron = hnl_tools.limits(flavor='e', invisible=True)
case_muon = hnl_tools.limits(flavor='mu', invisible=True)
case_tau = hnl_tools.limits(flavor='tau', invisible=True)

# %% [markdown]
# #### Start by printing the combination of all lines to file

# %%
x=np.geomspace(1,5e4)

np.save("combined_limits/Ue4_inv", np.array([x,case_electron.interp_func_all(x)]))
np.savetxt("combined_limits/Ue4_inv.dat", np.array([x,case_electron.interp_func_all(x)]).T)
x,y = np.load("combined_limits/Ue4_inv.npy")
x,y = np.loadtxt("combined_limits/Ue4_inv.dat", unpack=True)

np.save("combined_limits/Umu4_inv", np.array([x,case_muon.interp_func_all(x)]))
np.savetxt("combined_limits/Umu4_inv.dat", np.array([x,case_muon.interp_func_all(x)]).T)
x,y = np.load("combined_limits/Umu4_inv.npy")
x,y = np.loadtxt("combined_limits/Umu4_inv.dat", unpack=True)

np.save("combined_limits/Utau4_inv", np.array([x,case_tau.interp_func_all(x)]))
np.savetxt("combined_limits/Utau4_inv.dat", np.array([x,case_tau.interp_func_all(x)]).T)
x,y = np.load("combined_limits/Utau4_inv.npy")
x,y = np.loadtxt("combined_limits/Utau4_inv.dat", unpack=True)

# %% [markdown]
# ## $|U_{e N}|^2$

# %%
kwargs = {
        'xrange': (5,5e4),
        'yrange': (1e-11,1e-1),
        'title': fr"$|U_{{\mu N}}|^2 = |U_{{\tau N}}|^2 = 0$, Dirac $N$",
        #
        #
        'skip_ids': [
                'dune_ballett',
                'fmmf',
                'bebc'
                ],
        #
        'new_color': {
                'bbn': 'black',
                'microboone_higgs': 'green',
                't2k_lowmass': 'blue',
                'dune_berryman': 'dodgerblue',
                'ship': 'firebrick'
                },
        #
        'new_dash': {
                'bbn': (1,1)
                },
        #
        'new_labelpos': {
                'bbn': (20, 4.5e-10),
                't2k': (180, 3e-9),
                'na62': (200, 1.2e-10),
                'na3': (1.e3, 3.5e-5),
                'charm': (200, 2e-5),
                'delphi_short': (2e4, 8e-6),
                'pienu': (50, 1e-8),
                'pienu_highmass': (900, 1.6e-3),
                'pienu_lowmass': (10, 0.5e-6),
                'de2_bryman_shrock': (300, 4e-4)}
        }

fig, ax = plot_tools.std_plot_limits(case_electron, suffix='_inv', **kwargs)

# %% [markdown]
# ## $|U_{\mu N}|^2$

# %%
kwargs = {'xrange': (5,5e3),
                            #
                            'skip_ids': ['dune_ballett','fmmf'],
                            #
                            'title': fr"$|U_{{e N}}|^2 = |U_{{\tau N}}|^2 = 0$, Dirac $N$",
                            #
                            'new_color': {
                                'bbn': 'black',
                                'microboone_higgs': 'green',
                                'pienu': 'pink',
                                't2k': 'blue',
                                't2k_lowmass': 'blue',
                                'dune_berryman': 'dodgerblue',
                                'ship': 'firebrick'},
                            #
                            'new_dash': {'bbn': (1,1)},
                            #
                            'new_labelpos': {
                                'bbn': (10, 6e-10),
                                'bebc': (232, 1.15e-4),
                                'charmii': (2e3, 1e-3),
                                'dune_berryman': (90, 8e-9),
                                'delphi_short': (2e4, 8e-6),
                                'ewpo': (1e4, 2e-3),
                                'fmmf': (500, 1e-5),
                                'ktev': (300, 2e-6),
                                'kek': (200, 3e-6),
                                'lepton_universality': (1e4, 5e-4),
                                'muon_decays': (20, 0.5e-2),
                                'microboone': (280, 3.5e-8),
                                'microboone_higgs': (50, 3e-4),
                                'nutev': (500, 1e-6),
                                'na62': (130, 4e-8),
                                'pienu': (20, 0.6e-6),
                                'sk': (120,0.4e-4),
                                'sin': (10, 3e-4),
                                'psi': (6, 3e-6),
                                'lepton_universality': (0.6e3, 1e-3),
                                't2k_lowmass': (40,7.5e-6),
                            }
        }


fig, ax = plot_tools.std_plot_limits(case_muon, suffix='_inv', **kwargs)

# %% [markdown]
# ## $|U_{\tau N}|^2$

# %%
kwargs = {'xrange': (5,5e4),
                            'yrange': (1e-10,1),
                            #
                            'skip_ids': ['dune_ballett','fmmf','t2k'],
                            #
                            'title': fr"$|U_{{e N}}|^2 = |U_{{\mu N}}|^2 = 0$, Dirac $N$",
                            #
                            'new_color': {
                            't2k': 'grey',
                            'bbn': 'black',
                            'nomad': 'darkorange',
                            'dune_berryman': 'dodgerblue',
                            'icecube': 'violet',
                            'ship': 'firebrick'}
                            ,
                            #
                            'new_dash': {
                                    'bbn': (1,1),
                                    't2k': (1,1)
                                    },
                            #
                            'new_labelpos': {'bbn': (300, 6e-10),
                                        'charm': (300, 4e-4),
                                        'charm_2021': (1.5e3, 2e-6),
                                        'dune_berryman': (0.7e3, 1.5e-7),
                                        'borexino_plestid': (10,1e-2),
                                        'lepton_universality_2': (1e4,8e-3),
                                        'b_decays': (3.4e3, 2e-2),
                                        'delphi_short': (2e4, 8e-6),
                                        'delphi_long': (5e3, 2e-4),
                                        'lepton_universality': (1e4, 5e-4),
                                        'ewpo': (1e4, 2e-3),
                                        'icecube': (1.8e3, 1.5e-5),
                                        }
}


fig, ax = plot_tools.std_plot_limits(case_tau, suffix='_inv', **kwargs)
