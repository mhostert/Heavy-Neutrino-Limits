# %% [markdown]
# ## Limits on 4-fermion NC operators $\mathcal{O}_\text{ff}$ & $\mathcal{O}_\text{LN}$ $-$ $\psi^4$
#
# This notebook plots the standard parameter space of heavy neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1TIpmkgOa63-8Sy75qh0YutI5XdRtiClU3aquUdmjqpc/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.HNLimits.FourFermion_NC import plot_tools
from src.HNLimits.FourFermion_NC import fourfermion_neutral_tools

# %% [markdown]
# ## $\dfrac{C_\text{ee}}{\Lambda^2}$ & $\dfrac{C_\text{LN}}{\Lambda^2}$

# %%
case_neutral_ee_LN = fourfermion_neutral_tools.Limits(flavor='ee_LN', invisible=False)

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-8,1e-3),
        #
        #
        'skip_ids': [
                ],
        #
        'new_color': {
                'monophoton': '#393E46',
                'sn': '#00ADB5', 
                },
        #
        'new_dash': {
                'sn': (6,2)
                },
        #
        'new_labelpos': {
                'monophoton': (1.4e-3, 5e-6),
                'sn': (1.4e-2, 3e-8)
                },
        #
        'new_rotation':{
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_neutral_ee_LN, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C_\text{uu}}{\Lambda^2}$

# %%
case_neutral_uu = fourfermion_neutral_tools.Limits(flavor='uu', invisible=False)

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-8,1e0),
        #
        'skip_ids': [

                ],
        #
        'new_color': {
                'na62': '#FFACAC', 
                'eta_decay': '#7DB9B6',  
                'etap_decay': '#F5E9CF',  
                'jpsi_decay': '#9E4784',  
                'monojet': '#4D455D',
                'sn': '#00ADB5'
                },
        #
        'new_dash': {
                'sn': (6,2)
                },
        #
        'new_labelpos': {
                'na62': (6e-2, 1.2e-5),
                'eta_decay': (1e-1, 1.4e-1),
                'etap_decay': (3e-1, 1.4e-1),
                'monojet': (1.4e-3, 2e-7),
                'jpsi_decay': (4e-1, 3e-4)
                },
        #
        'new_rotation':{
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_neutral_uu, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C_\text{dd}}{\Lambda^2}$

# %%
case_neutral_dd = fourfermion_neutral_tools.Limits(flavor='dd', invisible=False)

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-8,1e0),
        #
        #
        'skip_ids': [
                #'sn'
                ],
        #
        'new_color': {
                'na62': '#FFACAC',
                'eta_decay': '#7DB9B6',
                'etap_decay': '#F5E9CF', 
                'phi_decay': '#B3E5BE',
                'upsilon_decay': '#E96479',
                'monojet': '#4D455D',
                'sn': '#00ADB5'
                },
        #
        'new_dash': {
                'sn': (6,2)
                },
        #
        'new_labelpos': {
                'na62': (6e-2, 1.2e-5),
                'eta_decay': (1.4e-1, 1.7e-3),
                'etap_decay': (3e-1, 2e-2),
                'monojet': (1.4e-3, 3e-7),
                'phi_decay': (1.4e-3, 4e-2),
                'upsilon_decay': (1.4e-3, 5e-5)
                },
        #
        'new_rotation':{
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_neutral_dd, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Generating the Latex files

# %%
from src.HNLimits.FourFermion_NC import tex_tools as tex
tex.create_latex_doc(cases=[case_neutral_ee_LN,case_neutral_uu,case_neutral_dd])
