# %% [markdown]
# ## Limits on Tensor operator $\mathcal{O}_\text{NW}$ $-$ $\psi^2 H F$
#
# This notebook plots the standard parameter space of heavy neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1TIpmkgOa63-8Sy75qh0YutI5XdRtiClU3aquUdmjqpc/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.HNLimits.Tensor import plot_tools
from src.HNLimits.Tensor import tensor_tools

# %% [markdown]
# ## $\dfrac{C_\text{NW}^e}{\Lambda^2}$

# %%
case_cnw_electron = tensor_tools.Limits(operator= 'CNW', flavor='e', invisible=False)

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (2e-13,1e-5),
        #
        'skip_ids': [
                'lep',
                'bbn'
                ],
        #
        'new_color': {
                'sn': '#00ADB5',
                'xenon': '#F5E9CF', 
                'borexino': '#4D455D', 
                'borexino_sk': '#E96479', 
                'lsnd': '#FFC75F',
                'sk_atm': '#4D375D',
                'lhc': '#41644A'
                },
        #
        'new_dash': {
                'sn': (4,2)
                },
        #
        'new_labelpos': {
                'xenon': (1.2e-3, 11e-9), 
                'lsnd': (60e-3,4.2e-9),
                'borexino': (1.2e-3, 2e-9),
                'borexino_sk': (4e-3,2.4e-10),
                'sn': (1.6e-1, 2e-11),
                'sk_atm': (6e-3,3e-9),
                'lhc': (1e1,5e-7)
                },
        #
        'new_rotation':{
                'sn':-27,
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_cnw_electron, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C_\text{NW}^\mu}{\Lambda^2}$

# %%
case_cnw_muon = tensor_tools.Limits(operator= 'CNW', flavor='mu', invisible=False)

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (2e-13,1e-5),
        #
        'skip_ids': [
                'lep',
                'bbn',
                'miniboone'
                ],
        #
        'new_color': {
                'sn': '#00ADB5',
                'xenon': '#F5E9CF',  
                'borexino': '#4D455D', 
                'borexino_sk': '#E96479',  
                'nomad': '#9E4784',  
                'charmii': '#7DB9B6',  
                'minerva': '#FF9D76',  
                'sk_atm': '#4D375D', 
                'lhc': '#41644A'
                },
        #
        'new_dash': {
                'sn': (4,2)
                },
        #
        'new_labelpos': {
                'xenon': (1.2e-3, 11e-9),
                'charmii': (14e-3,2.2e-9),
                'minerva': (1e-1,10e-10),
                'nomad': (1e0,3.6e-9),                 
                'borexino': (1.2e-3, 2e-9),
                'borexino_sk': (4e-3,2.4e-10),
                'sn': (1.6e-1, 2e-11),
                'sk_atm': (6e-3,3e-9),
                'lhc': (1e1,5e-7)
                },
        #
        'new_rotation':{
                'sn':-27,
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_cnw_muon, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C_\text{NW}^\tau}{\Lambda^2}$

# %%
case_cnw_tau = tensor_tools.Limits(operator= 'CNW', flavor='tau', invisible=False)

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (2e-13,1e-5),
        #
        'skip_ids': [
                'lep',
                'bbn'
                ],
        #
        'new_color': { 
                'sn': '#00ADB5',
                'xenon': '#F5E9CF',  
                'borexino': '#4D455D',  
                'borexino_sk': '#E96479',  
                'sk_atm': '#4D375D',
                'donut': '#FFC75F',  
                'lhc': '#41644A'
                },
        #
        'new_dash': {
                'sn': (4,2)
                },
        #
        'new_labelpos': {
                'xenon': (1.2e-3, 11e-9),
                'donut': (1.4e-1,4e-7),
                'borexino': (1.2e-3, 2e-9),
                'borexino_sk': (4e-3,2.4e-10),
                'sn': (1.6e-1, 2e-11),
                'bbn': (1.2e-3, 7.6e-12),
                'sk_atm': (6e-3,4e-9),
                'lhc': (1e1,5e-7)
                },
        #
        'new_rotation':{
                'sn':-27,
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_cnw_tau, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Generating the Latex files

# %%
from src.HNLimits.Tensor import tex_tools as tex
tex.create_latex_doc(cases=[case_cnw_electron,case_cnw_muon,case_cnw_tau])
# Out:
# Latexmk: This is Latexmk, John Collins, 19 Jan. 2017, version: 4.52c.
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       '/Users/sissa/Documents/GitHub/Heavy-Neutrino-Limits/tex_files/std_plots.tex'
#       'std_plots.tex'
#    Non-existent destination files:
#       'std_plots.pdf'
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  --interaction=nonstopmode -recorder  "/Users/sissa/Documents/GitHub/Heavy-Neutrino-Limits/tex_files/std_plots.tex"'
# ------------
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.14159265-2.6-1.40.18 (TeX Live 2017) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (/Users/sissa/Documents/GitHub/Heavy-Neutrino-Limits/tex_files/std_plots.tex
# LaTeX2e <2017-04-15>
# Babel <3.10> and hyphenation patterns for 84 language(s) loaded.
#
# ! LaTeX Error: File `revtex4-2.cls' not found.
#
# ...
