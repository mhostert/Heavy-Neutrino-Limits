# %% [markdown]
# # Limits on 4-fermion CC operator $\mathcal{O}_{\text{LNQd}}$ $-$ $\psi^4$
#
# This notebook plots the standard parameter space of heavy neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1TIpmkgOa63-8Sy75qh0YutI5XdRtiClU3aquUdmjqpc/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.HNLimits.FourFermion_CC import plot_tools
from src.HNLimits.FourFermion_CC import fourfermion_charged_tools

# %% [markdown]
# ## $\dfrac{C_{\text{LNQd}}^e}{\Lambda^2}$

# %%
case_electron = fourfermion_charged_tools.Limits(flavor='LNQd_e', invisible=False, nature='majorana')

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (6e-12,1e-5),
        #
        'skip_ids': [
                'borexino',
                'charm',
                'atlas_2019_prompt',
                'atlas_2022',
                'cms_2022',
                'delphi_long',
                'delphi_short',
                'pmns_unitarity',
                'belle'
                ],
        #
        'new_color': {
                'pienu_lowmass_fb': '#E36387', 
                'triumf_fb': '#354259', 
                'pienu_2017_fb': '#BFB051', 
                't2k_fb': '#FA697C', 
                'kenu_fb': '#FFCAC8', 
                'na62_fb': '#8DCBE6',
                'bebc_barouki_fb': '#8F4068',
                'monolepton_fb': '#4D455D', 
                'pienu_lowmass_fa': '#E36387', 
                'triumf_fa': '#354259', 
                'pienu_2017_fa': '#BFB051', 
                't2k_fa': '#FA697C', 
                'kenu_fa': '#FFCAC8', 
                'na62_fa': '#8DCBE6',
                'bebc_barouki_fa': '#8F4068',
                'monolepton_fa': '#4D455D'
                },
        #
        'new_dash': {
                },
        #
        'new_labelpos': {
                'pienu_lowmass_fb': (1.4e-3, 7e-11),
                'triumf_fb': (26e-3, 7e-11),
                'pienu_2017_fb': (50e-3, 2e-11),
                'na62_fb': (124e-3, 1.2e-11),
                't2k_fb': (540e-3, 8e-11),
                'kenu_fb': (8e-3, 6e-11),
                'bebc_barouki_fb': (1,1.3e-9),
                'monolepton_fb': (1.4e-3,4e-7),
                'pienu_lowmass_fa': (1.4e-3, 7e-1),
                'triumf_fa': (26e-3, 7e-1),
                'pienu_2017_fa': (50e-3, 2e-1),
                'na62_fa': (124e-3, 1.2e-1),
                't2k_fa': (540e-3, 8e-1),
                'kenu_fa': (8e-3, 6e-1),
                'bebc_barouki_fa': (1,1.3e-1),
                'monolepton_fa': (1.4e-3,4e-1)
                },
        #
        'new_rotation':{
                't2k_fb': 90,
                'na62_fb': 90
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_electron, color_fill=True, **kwargs)

# %% [markdown]
# ## $\dfrac{C_{\text{LNQd}}^\mu}{\Lambda^2}$

# %%
case_muon = fourfermion_charged_tools.Limits(flavor='LNQd_mu', invisible=False, nature='majorana')

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (6e-12,1e-5),
        #
        'skip_ids': [
            'delphi_short',
            't2k_lowmass',
            'microboone_higgs',
            'atlas_2019_prompt',
            'cms_2022',
            'atlas_2022',
            'pmns_unitarity',
            'na3'
        ],
        #
        'new_color': {
            'psi_fb': '#A0C3D2', 
            'pienu_le_fb': '#F29191',
            'pienu_he_fb': '#F29191',  
            't2k_fb': '#FA697C', 
            'kek_fb': '#BAABDA', 
            'na62_fb': '#8DCBE6', 
            'nutev_fb': '#41AEA9',
            'bebc_fb': '#8F4068', 
            'monolepton_fb': '#4D455D',
            'e949_fb': '#F1C93B',
            'psi_fa': '#A0C3D2', 
            'pienu_le_fa': '#F29191',
            'pienu_he_fa': '#F29191', 
            't2k_fa': '#FA697C', 
            'kek_fa': '#BAABDA', 
            'na62_fa': '#8DCBE6', 
            'nutev_fa': '#41AEA9',
            'bebc_fa': '#8F4068', 
            'monolepton_fa': '#4D455D',
            'e949_fa': '#F1C93B'
        },
        #
        'new_dash': {
        },
        #
        'new_labelpos': {
            'psi_fb': (8e-3,14e-10),
            'pienu_le_fb': (21e-3,10e-1),
            'pienu_he_fb': (20e-3,6.7e-10),
            't2k_fb': (4.2e-1,6e-11),
            'bebc_fb': (1.1,1.2e-9),
            'nutev_fb': (5e-1,12e-10),
            'na62_fb': (3e-1, 2.6e-11),
            'kek_fb': (1e-1,2.6e-10),
            'monolepton_fb': (1.4e-3,6e-7),
            'e949_fb': (1.7e-1, 1.6e-11),
            'psi_fa': (8e-3,14e-1),
            'pienu_le_fa': (21e-3,10e-1),
            'pienu_he_fa': (20e-3,6.7e-1),
            't2k_fa': (3.4e-1,2.4e-1),
            'bebc_fa': (1.1,1.2e-1),
            'nutev_fa': (5e-1,12e-1),
            'na62_fa': (2e-1, 2.4e-1),
            'kek_fa': (1e-1,2.6e-1),
            'monolepton_fa': (1.4e-3,6e-1),
            'e949_fa': (2e-1, 2.4e-1),
        },
        'new_rotation': {
            'pienu_le_fb': 90,
            't2k_fb': 90
        }
    }

fig, ax = plot_tools.std_plot_limits(case_muon, color_fill=True, **kwargs)

# %% [markdown]
# ## $\dfrac{C_{\text{LNQd}}^\tau}{\Lambda^2}$

# %%
case_tau = fourfermion_charged_tools.Limits(flavor='LNQd_tau', invisible=False, nature='majorana')

# %%
kwargs = {
    'xrange': (1e-3,1e2),
    'yrange': (6e-11,1e-4),
    #
    'skip_ids': [
            'bebc_fb'
                ],
    #
    'new_color': {
        'd_decay_fb': '#E96479', 
        'ds_decay_fb': '#F5E9CF', 
        'b_decay_fb': '#7DB9B6', 
        'monolepton_fb': '#4D455D',
        'd_decay_fa': '#E96479',
        'ds_decay_fa': '#F5E9CF',
        'b_decay_fa': '#7DB9B6',
        'monolepton_fa': '#4D455D'
    }
    ,
    #
    'new_dash': {
    },
    #
    'new_labelpos': {
        'b_decay_fb': (1.4e-3, 1.1e-8),
        'd_decay_fb': (1.4e-3, 7e-7),
        'ds_decay_fb': (1.4e-3, 3e-6),
        'monolepton_fb': (1.4e-3, 15e-8),
        'b_decay_fa': (1.4e-3, 1.1e-1),
        'd_decay_fa': (1.4e-3, 7e-1),
        'ds_decay_fa': (1.4e-3, 3e-1),
        'monolepton_fa': (1.4e-3, 15e-1),
    },
    #
    "new_rotation": {

    }
}

fig, ax = plot_tools.std_plot_limits(case_tau, color_fill=True, **kwargs)

# %% [markdown]
# # Generating the Latex files

# %%
from src.HNLimits.FourFermion_CC import tex_tools as tex
tex.create_latex_doc(cases=[case_electron,case_muon,case_tau])
