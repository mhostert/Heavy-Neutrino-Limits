# %% [markdown]
# ## Relevant Limits on Heavy Neutrino Mixing (Majorana case)
#
# This notebook plots the standard parameter space of heavy Majorana neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1WAbk-k_mcgMyzQ3fg5BhnWdYY-tq8OJ9IRLNqzQXgJ8/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import *
from Nlimits_final import plot_tools
from Nlimits_final import hnl_tools
import matplotlib.pyplot as plt

# %% [markdown]
# ## $|U_{e N}|^2$

# %%
case_electron = hnl_tools.Limits(flavor='e', invisible=False, nature='majorana')

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-10,1e-1),
        #
        'skip_ids': [
                ],
        #
        'new_color': {
                'borexino': '#BAABDA', 
                'pienu_lowmass': '#E36387', 
                'triumf': '#354259', 
                'pienu_2017': '#BFB051', 
                't2k': '#FF8AAE',
                'kenu': '#FFC7C7', 
                'na62': '#9AD0EC',
                'charm': '#7D9D9C',
                'bebc_barouki': '#8F4068',
                'belle': '#423F3E',
                'delphi_short': '#D1D1D1', 
                'atlas_2019_prompt': '#1572A1', 
                'atlas_2022': '#F69E7B', 
                'cms_2022': '#9A86A4', 
                'delphi_long': '#A3D2CA',
                'pmns_unitarity': '#F29191', 
                'cosmo': 'grey'
                },
        #
        'new_dash': {
                'cosmo': (4,2)
                },
        #
        'new_labelpos': {
                'borexino': (4.2e-3,1.7e-6),
                'pienu_lowmass': (1.4e-3,1.2e-5),
                'kenu': (240e-3,3.4e-8),
                'triumf': (60e-3,1.2e-8),
                'pienu_2017': (64e-3,1.2e-9),
                't2k': (5.2e-1,2e-9),
                'na62': (230e-3, 1.7e-10),
                'bebc_barouki': (1.1,1.5e-8),
                'charm': (2.16,2e-7),
                'belle': (1.2e0,1.4e-5),
                'delphi_long': (5e-1,2e-4),
                'delphi_short': (4e1,0.8e-5),
                'cms_2022': (1.38e1,2e-6),
                'atlas_2019_prompt': (2e1,6e-6),
                'atlas_2022': (7,1.4e-7),
                'pmns_unitarity': (2e1,1.3e-3),
                'cosmo': (1.4e-3,2e-10)
                },
        #
        'new_rotation':{
                'borexino':-23,
                'pienu_lowmass': -23,
                'kenu': 0,
                't2k': 90,
                'charm': 90,
                'belle': -23,
                'delphi_long':-40,
                'cms_2022': 90
        },
        #
        }

fig, ax = plot_tools.std_plot_limits(case_electron, color_fill=True, **kwargs)

# %% [markdown]
# ## $|U_{\mu N}|^2$

# %%
case_muon = hnl_tools.Limits(flavor='mu', invisible=False, nature='majorana')

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-10,1e-1),
        #
        'skip_ids': [
        ],
        #
        'new_color': {
            'psi': '#8DB596',
            'pienu_le': '#C6D57E',
            'pienu_he': '#D57E7E', 
            'microboone_higgs': '#EEC4C4', 
            't2k_lowmass': '#707070', 
            't2k': '#FF8AAE', 
            'na62': '#9AD0EC', 
            'nutev': '#A2CDCD', 
            'bebc': '#F4EEED', 
            'na3': '#EEBB4D', 
            'delphi_short': '#D1D1D1',  
            'atlas_2022': '#F69E7B', 
            'cms_2022': '#9A86A4', 
            'atlas_2019_prompt': '#1572A1', 
            'pmns_unitarity': '#F29191', 
            'cosmo': 'grey'
        },
        #
        'new_dash': {
            'cosmo': (4,2)
        },
        #
        'new_labelpos': {
            'psi': (10e-3,3.1e-6),
            'pienu_le': (21e-3,10e-6),
            'pienu_he': (13e-3,7.2e-7),
            't2k_lowmass': (34e-3,3e-6),
            'microboone_higgs': (80e-3,2e-7),
            'na3': (1.1,7e-6),
            'nutev': (1.92,7e-8),
            'bebc': (4e-1,5e-7),
            't2k': (4e-1, 9e-10),
            'na62': (4.1e-1, 7e-9),
            'delphi_short': (4.2e1,7e-6),
            'cms_2022': (1.6e1,8e-7),
            'atlas_2019_prompt': (2e1,5e-6),
            'atlas_2022': (8,1.2e-7),
            'pmns_unitarity': (1.6e1,8e-5),
            'cosmo': (1.2e-3,2e-10)
        },
        'new_rotation': {
            'pienu_le': 90,
            't2k_lowmass': -34,
            'microboone_higgs': -40,
            'na3': -36,
            'nutev': 90,
            'bebc': -39,
            't2k': 90,
            'na62': 90,
            'cms_2022': 90
        }
    }

fig, ax = plot_tools.std_plot_limits(case_muon, color_fill=True, **kwargs)

# %% [markdown]
# ## $|U_{\tau N}|^2$

# %%
case_tau = hnl_tools.Limits(flavor='tau', invisible=False, nature='majorana')

# %%
kwargs = {
    'xrange': (1e-3,1e2),
    'yrange': (1e-10,4e-1),
    #
    'skip_ids': [
                ],
    #
    'new_color': {
        'borexino_plestid': '#BAABDA',
        'charm': '#6886C5',  
        'charm_2021': '#7D9D9C', 
        'bebc_barouki': '#8F4068',
        'delphi_short': '#D1D1D1', 
        'delphi_long': '#A3D2CA',
        'pmns_unitarity': '#F29191', 
        'cosmo': 'gray',
        'babar_2022': '#423F3E', 
        'argoneut': '#E4D192', 
        'atmospheric': '#E36387'
    },       
    #
    'new_dash': {
        'cosmo': (4,2)
    },
    #
    'new_labelpos': {
        'borexino_plestid': (4.2e-3, 8e-3),
        'charm': (40e-3, 2.6e-4),
        'charm_2021': (3e-1,8e-7),
        'delphi_long': (2,6e-6),
        'delphi_short': (10,5.6e-6),
        'pmns_unitarity': (2e1,7e-4),
        'cosmo': (1.2e-3,2e-10),
        'argoneut': (3.4e-1,5e-4),
        'babar_2022': (1.34,5e-6),
        'atmospheric': (1.2e-3,5e-2)
    },
    #
    "new_rotation": {
        'charm': -40,
        'charm_2021': -36,
        'argoneut': -49,
        'borexino_plestid': -32,
        'babar_2022': 90
    }
}
fig, ax = plot_tools.std_plot_limits(case_tau, color_fill=True, **kwargs)

# %%
# from Nlimits import tex_tools as tex
# tex.create_latex_doc(cases=[case_electron,case_muon,case_tau])
