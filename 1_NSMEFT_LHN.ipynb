# %% [markdown]
# ## Limits on Higgs Dressed operator $-$ $\psi^2 H^3$
#
# This notebook plots the standard parameter space of heavy neutrinos under the assumption of single flavor dominance.
#
# The data is pulled from [this spreadsheet](https://docs.google.com/spreadsheets/d/1T_EKnPEL3Ntoy1m5z4vI4KGkKtJxQCdgxmiQxSs43DY/edit?usp=sharing), and limits are drawn from digitized or shared data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.HNLimits.HiggsDressed import plot_tools
from src.HNLimits.HiggsDressed import higgsdressed_tools

# %% [markdown]
# ## $\dfrac{C^e_\text{LNH}}{\Lambda^2}$

# %%
case_electron = higgsdressed_tools.Limits(flavor='e', invisible=False, nature='majorana')

# %%
kwargs = {
        'xrange': (1e-3,1e2),
        'yrange': (1e-13,1e-6),
        #
        'skip_ids': [
                'pmns_unitarity',
                'atlas_2019_prompt'
                ],
        #
        'new_color': {      
                'borexino': '#BAABDA',
                'pienu_lowmass': '#E36387',
                'triumf': '#354259', 
                'pienu_2017': '#BFB051', 
                't2k': '#FA697C', 
                'kenu': '#FFCAC8', 
                'na62': '#8DCBE6',
                'charm': '#43919B',
                'bebc_barouki': '#8F4068',
                'belle': '#423F3E',
                'delphi_long': '#98DED9', 
                'delphi_short': '#93329E',  
                'atlas_2022': '#A799B7', 
                'cms_2022': '#FF9668', 
                'cms_2018': '#7579E7',
                'hinv': '#4D455D', 
                },
        #
        'new_dash': {
                },
        #
        'new_labelpos': {
                'hinv': (1.4e-3, 5e-8),
                'numass': (0.9e-2, 2.4e-13),
                'pienu_lowmass': (1.4e-3, 1.8e-12),
                'borexino': (4e-3, 1.4e-12),
                'triumf': (26e-3, 1.8e-12),
                'pienu_2017': (35e-3, 9e-13),
                'na62': (124e-3, 10e-13),
                't2k': (530e-3, 3e-12),
                'bebc_barouki': (1,2.1e-11),
                'charm': (2.2,1e-10),
                'belle': (5e-1,0.8e-9),
                'delphi_long': (0.5, 2.5e-9),
                'atlas_2022': (4.4,5e-10),
                'cms_2022': (14,3e-9),
                'cms_2018': (20,7e-9),
                'delphi_short': (40, 1.8e-8),
                },
        #
        'new_rotation':{
                'charm':90,
                'numass': 10,
                't2k': 90,
                'delphi_long': -10,
                'cms_2022': 90,
                'na62': 90,
        }
        #
}

fig, ax = plot_tools.std_plot_limits(case_electron, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C^\mu_\text{LNH}}{\Lambda^2}$

# %%
case_muon = higgsdressed_tools.Limits(flavor='mu', invisible=False, nature='majorana')

# %%
kwargs = {
    'xrange': (1e-3,1e2),
    'yrange': (1e-13,1e-6),
    #
    'skip_ids': [
        'pmns_unitarity',
        'cms_8tev',
        'cms_2018_dilepton'
    ],
    #
    'new_color': {     
            'psi': '#A0C3D2', 
            'pienu_le': '#F29191',
            'pienu_he': '#F29191',  
            't2k_lowmass': '#381460',
            't2k': '#FA697C', 
            'kek': '#BAABDA', 
            'na62': '#8DCBE6', 
            'nutev': '#41AEA9', 
            'bebc': '#8F4068', 
            'na3': '#8BCDCD', 
            'delphi_short': '#93329E',  
            'atlas_2019_prompt': '#120078', 
            'atlas_2022': '#A799B7', 
            'cms_2022': '#FF9668', 
            'cms_2018_trilepton': '#7579E7',
            'hinv': '#4D455D'
    },
    #
    'new_dash': {
    },
    #
        'new_labelpos': {
                'hinv': (1.4e-3, 5e-8),
                'pienu_le': (3e-2, 0.9e-21),
                'pienu_he': (2e-2, 2.8e-12),
                't2k_lowmass': (4e-2, 3e-11),
                'na62': (2e-1, 1.8e-12),
                't2k': (4.1e-1, 2.4e-12),
                'nutev': (9e-1,3.2e-11),
                'na3': (1.2,7.4e-10),
                'bebc': (0.4,8e-11),
                'kek': (0.11,1.4e-11),
                'atlas_2022': (12,6e-10),
                'cms_2022': (4,4.2e-10),
                'atlas_2019_prompt': (28,12e-9),
                'delphi_short': (16, 5e-9),
                'cms_2018_trilepton': (60,3e-8)
                },
    #
        'new_rotation':{
                'charm':90,
                'bebc': -10,
                't2k': 90
                        }
    #
}

fig, ax = plot_tools.std_plot_limits(case_muon, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## $\dfrac{C^{\tau}_{LNH}}{\Lambda^2}$

# %%
case_tau = higgsdressed_tools.Limits(flavor='tau', invisible=False, nature='majorana')

# %%
kwargs = {
    'xrange': (1e-3,1e2),
    'yrange': (1e-13,1e-6),
    #
    'skip_ids': [
        'pmns_unitarity'
                ],
    #
    'new_color': {
        'borexino_plestid': '#BAABDA', 
        'charm': '#ECA0B6', 
        'charm_2021': '#43919B', 
        'bebc_barouki': '#8F4068',
        'delphi_long': '#98DED9', 
        'delphi_short': '#93329E',  
        'cosmo': 'gray',
        'babar_2022': '#423F3E',  
        'argoneut': '#F6F6D9', 
        'atmospheric': '#7149C6', 
        'hinv': '#4D455D', 
    }
    ,
    #
    'new_dash': {
    },
    #
    'new_labelpos': {
        'borexino_plestid': (6e-3, 1.6e-10),
        'charm': (30e-3, 3e-10),
        't2k': (2e-1, 5.4e-11),
        'charm_2021': (4e-1, 1.2e-10),
        'bebc_barouki': (1.2,1.4e-10),
        'delphi_long': (2,1.3e-9),
        'delphi_short': (10,3.4e-9),
        'pmns_unitarity': (3,2e-8),
        'hinv': (1.2e-3, 5e-8),
        'atmospheric': (1.2e-3,4e-11),
        'babar_2022': (1.36,6.4e-10),
        'argoneut': (2.4e-1,2.8e-9)
    },
    #
    "new_rotation": {
        'charm': -7,
        'delphi_short': 16,
        'atmospheric': 16,
        'babar_2022': 90,
        'argoneut': -32
    }
}

fig, ax = plot_tools.std_plot_limits(case_tau, color_fill=True, **kwargs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Generating the Latex files

# %%
from src.HNLimits.HiggsDressed import tex_tools as tex
tex.create_latex_doc(cases=[case_electron,case_muon,case_tau])
# Out:
# Latexmk: This is Latexmk, John Collins, 19 Jan. 2017, version: 4.52c.
# Rule 'bibtex hd_plots': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       'hd_plots.bib'
#    Non-existent destination files:
#       'hd_plots.bbl'
# ------------
# Run number 1 of rule 'bibtex hd_plots'
# ------------
# ------------
# Running 'bibtex  "hd_plots"'
# ------------
# Latexmk: applying rule 'bibtex hd_plots'...
# For rule 'bibtex hd_plots', running '&run_bibtex(  )' ...
# This is BibTeX, Version 0.99d (TeX Live 2017)
# The top-level auxiliary file: hd_plots.aux
# The style file: apsrev4-1.bst
# Database file #1: hd_plotsNotes.bib
# Database file #2: hd_plots.bib
# Warning--I didn't find a database entry for "Workinprogress"
# merlin.mbs apsrev4-1.bst 2010-07-25 4.21a (PWD, AO, DPC) hacked
# Control: key (0)
# Control: author (72) initials jnrlst
# Control: editor formatted (1) identically to author
# Control: production of article title (-1) disabled
# ...
